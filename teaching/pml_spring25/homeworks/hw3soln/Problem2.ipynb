# %% [markdown]
# For this question, the main work is to derive the posterior distribution for each of the four possible states as we do not explicitly keep track of $X_t$ values.
#
# The likelihood computation involved in the weight update given on step (c) on pg 890, requires computing predictive likelihood $p(y_t | y_{\tau:t-1})$ when $S_t = 1$.
#
# We are given $\sigma=10000$, $\tau_1 = 2500$ and $\tau_2 = 12500$ and $\mu = 115000$, $\nu = 85000$.
#
# We will use 100 as the maximum number of particles.
#
# # Posterior update
#
# ## Case 1: $S_t = 2$ and $O_t = 1$.
#
# In this case, we have a new change point. So we set $\tau = t$.
#
# And the posterior distribution is given by
#
# $$p(x_t | y_t) = \frac{p(y_t | x_t) p(x_t)}{p(y_t)}.$$
#
# Since we have Normal prior $X_t \sim \text{Normal}(\mu, \sigma^2)$ and Normal likelihood $Y_t | X_t = x\sim \text{Normal}(x, \tau_1^2)$, we have conjugacy.
#
# We are given the values of $\sigma, \tau_1$, so we fall in the case of Normal distribution with unknown $\mu$ but known variance (see [Wikipedia](https://en.wikipedia.org/wiki/Conjugate_prior#When_likelihood_function_is_a_continuous_distribution)).
#
# The posterior update with sufficient statistic $\phi_t = y_t$:
#
# \begin{align*}
#     \gamma_t^2 &= \left( \frac{1}{\sigma^2} + \frac{1}{\tau_1^2} \right)^{-1} \\
#     \alpha_t &= \gamma_t^2 \left(\frac{\mu}{\sigma^2} + \frac{\phi_t}{\tau_1^2} \right)
# \end{align*}
#
# ## Case 2: $S_t = 1$ and $O_t = 1$.
#
# Let $\tau < t$ be the time of last change point. The posterior distribution in this case is given by
#
# \begin{align*}
#     p(x_t | y_{\tau:t}) = \frac{p(y_t | x_t) p(x_t | y_{\tau:t-1})}{p(y_t | y_{\tau:t-1})}.
# \end{align*}
#
# Note that $p(x_t | y_{\tau:t-1})$ denotes the predictive distribution but can also be seen as an updated prior after seeing $\tau:t-1$ data points.
#
# \begin{align*}
#   p(x_t | y_{\tau:t-1}) &= \int p(x_t | x_{t-1}) p(x_{t-1} | y_{\tau:t-1}) dx_{t-1} \\
#   &= p(x_{t-1} | y_{\tau:t-1}).
# \end{align*}
#
# since $s_t = 1$, we have $p(x_t | x_{t-1}) = 1[x_t = x_{t-1}]$.
#
# By induction (or recursion argument), we can see that $p(x_{t-1} | y_{\tau:t-1})$ is Normal distribution (the base case given in Case 1 above for $s_t = 2, o_t=1$) with mean and variance given by,
#
# \begin{align*}
#     \gamma_{t-1}^2 &= \left( \frac{1}{\sigma^2} + \frac{t - \tau}{\tau_1^2} \right)^{-1} \\
#     \alpha_{t-1} &= \gamma_t^2 \left(\frac{\mu}{\sigma^2} + \frac{\phi_{t-1}}{\tau_1^2} \right),
# \end{align*}
#
# with sufficient statistic $\phi_{t-1} = \sum_{i=\tau}^{t-1} y_i$.
#
# Keeping track of the sufficient statistic is recommended for computational efficiency. Given $\phi_{t-1}$, we just need $O(1)$ computation to update the sufficient stat at time $t$: $\phi_{t} = \phi_{t-1} + y_t$.
#
# With $x_t | y_{\tau:t-1} \sim N(\alpha_{t-1}, \gamma_{t-1}^2)$ as prior and $y_t | x_t \sim \text{Normal}(x_t, \tau_1^2)$, we obtain the following update:
#
# \begin{align*}
#     \gamma_t^2 &= \left( \frac{1}{\sigma^2} + \frac{t - \tau + 1}{\tau_1^2} \right)^{-1} \\
#     \alpha_t &= \gamma_t^2 \left(\frac{\mu}{\sigma^2} + \frac{\phi_t}{\tau_1^2} \right)
# \end{align*}
#
# ## Case 3: $S_t = 1$ and $O_t = 2$.
#
# We have a new change point so we set $\tau = t$, but the observation is an outlier. In this case, the posterior is unchanged from the previous time point:
#
# $$p(x_t | y_{\tau:t}) = p(x_t | y_{\tau:t-1}).$$
#
# This is because when $O_t = 2$, the value of $y_t$ is independent of $x_t$:
#
# \begin{align*}
#     p(x_t | y_{\tau:t}) &= \frac{p(y_t | x_t) p(x_t | y_{\tau:t-1})}{\int p(y_t | x_t) p(x_t | y_{\tau:t-1})dx_t}  \\
#     &= \frac{p(y_t) p(x_t | y_{\tau:t-1})}{p(y_t)} \\
#     &= p(x_{t-1} | y_{\tau:t-1}),
# \end{align*}
#
# where the last line is because $x_t = x_{t-1}$ since $S_t = 1$.
#
# ## Case 4: $S_t = 2$ and $O_t = 2$.
#
# We again have a new change point so we set $\tau = t$, but the observation is an outlier. In this case, the posterior is equal to the prior:
#
# $$p(x_t | y_t) = p(x_t) = \text{Normal}(\mu, \sigma^2).$$
#
# # Predictive likelihood
#
# ## $S_t = 1$ and $O_t = 1$.
#
# We have $x_t | y_{\tau:t-1} \sim \text{Normal}(\alpha_{t-1}, \gamma_{t-1}^2)$ and $y_t | x_t \sim \text{Normal}(x_t, \tau_1^2)$. The predictive is
#
# $$\text{Normal}(\alpha_{t-1}, \gamma_{t-1}^2 + \tau_1^2).$$
#
# ## $S_t = 2$ and $O_t = 1$.
#
# $$\text{Normal}(\mu, \sigma^2 + \tau_1^2).$$

# %%
import numpy as np
import scipy.stats as ss
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
from problem2 import *

# %%
well_data = pd.read_csv("welldata.csv", header=None)
Y = well_data.to_numpy()[:,0]
T = len(Y)

# %%
#pyplot.scatter(np.arange(len(Y)), Y)

# %%
max_particles = 100
mu = 115000
sigma = 10000
nu = 85000
tau_1 = 2500
tau_2 = 12500
cp_prob = 1./250

tt = T # set it to a small number for test stage.
pops = run_pf(Y[0:tt], max_particles, mu, sigma, nu, tau_1, tau_2, cp_prob)
# Out:
# Iteration 0.
# Iteration 1.
# Iteration 2.
# Iteration 3.
# # of particles to sample:5, stratum length:3.213537184821765e-15, uniform:6.589803336118542e-16
# Iteration 4.
# # of particles to sample:16, stratum length:7.530775095783549e-13, uniform:4.127811415636984e-13
# Iteration 5.
# # of particles to sample:14, stratum length:3.2048872708890573e-10, uniform:1.7929446396753445e-10
# Iteration 6.
# # of particles to sample:23, stratum length:6.190555670133504e-08, uniform:5.6780612262470324e-08
# Iteration 7.
# # of particles to sample:27, stratum length:1.1019576698178288e-06, uniform:5.204734821846655e-07
# Iteration 8.
# # of particles to sample:30, stratum length:3.577537488739794e-05, uniform:4.941836534423923e-06
# Iteration 9.
# # of particles to sample:24, stratum length:0.00010944898975656193, uniform:7.487286132666087e-05
# Iteration 10.
# # of particles to sample:46, stratum length:0.00026845338718814286, uniform:1.434274904615758e-07
# Iteration 11.
# # of particles to sample:20, stratum length:0.00016954166699843407, uniform:5.5748949081342205e-05
# Iteration 12.
# # of particles to sample:45, stratum length:0.0006421004669717867, uniform:0.00042477233976074825
# Iteration 13.
# # of particles to sample:36, stratum length:0.0007795538294719786, uniform:0.0005913793102082947
# Iteration 14.
# # of particles to sample:40, stratum length:0.0007941829394168957, uniform:0.00038606429303346813
# Iteration 15.
# # of particles to sample:42, stratum length:0.0004374060730328841, uniform:0.00033568193301077286
# Iteration 16.
# # of particles to sample:30, stratum length:0.00023038237073467127, uniform:0.00018301272286329063
# Iteration 17.
# # of particles to sample:24, stratum length:0.0009075878816180079, uniform:0.00027175285648188725
# Iteration 18.
# # of particles to sample:27, stratum length:0.0006576422676151369, uniform:0.0002280779651427851
# Iteration 19.
# # of particles to sample:58, stratum length:0.0035355233341118238, uniform:0.00019182485602980943
# Iteration 20.
# # of particles to sample:39, stratum length:0.0004820751231009833, uniform:0.0002779771491505214
# Iteration 21.
# # of particles to sample:32, stratum length:0.00011517984025094054, uniform:1.8262930768297643e-05
# Iteration 22.
# # of particles to sample:32, stratum length:0.00011488738684553407, uniform:0.00010047434159978687
# Iteration 23.
# # of particles to sample:36, stratum length:9.968864966557477e-05, uniform:2.9998620907049836e-06
# Iteration 24.
# # of particles to sample:39, stratum length:0.00011020891403926717, uniform:4.270468913175822e-05
# Iteration 25.
# # of particles to sample:40, stratum length:0.0001284090878213703, uniform:0.00011771893155941618
# Iteration 26.
# # of particles to sample:39, stratum length:0.000174871958724466, uniform:0.00017105005698495062
# Iteration 27.
# # of particles to sample:43, stratum length:0.0003520905824874843, uniform:0.0001709343171407474
# Iteration 28.
# # of particles to sample:28, stratum length:0.002044129867947374, uniform:0.0018831604136292533
# Iteration 29.
# # of particles to sample:18, stratum length:0.0010284430855610053, uniform:0.00013245521171052356
# Iteration 30.
# # of particles to sample:26, stratum length:0.0005906931191610375, uniform:0.00019877634659905806
# Iteration 31.
# # of particles to sample:24, stratum length:0.00036496914411220083, uniform:0.00030972729512325145
# Iteration 32.
# # of particles to sample:22, stratum length:0.00035609632540048697, uniform:0.00029036231443591183
# Iteration 33.
# # of particles to sample:23, stratum length:0.0003383716804921306, uniform:2.510382550854989e-05
# Iteration 34.
# # of particles to sample:15, stratum length:0.0002580556815974473, uniform:0.00022206841668243168
# Iteration 35.
# # of particles to sample:24, stratum length:0.00032944796615091927, uniform:1.4650428768471037e-05
# Iteration 36.
# # of particles to sample:24, stratum length:0.0003188191087607003, uniform:0.0001950163742462955
# Iteration 37.
# # of particles to sample:28, stratum length:0.0005134058948264945, uniform:0.00010223428957009313
# Iteration 38.
# # of particles to sample:18, stratum length:0.0004953358656651974, uniform:0.0002096305132684941
# Iteration 39.
# # of particles to sample:20, stratum length:0.0004901530719989543, uniform:0.00010758010249780351
# Iteration 40.
# # of particles to sample:12, stratum length:0.0004072604986695815, uniform:0.0003165394609203039
# Iteration 41.
# # of particles to sample:17, stratum length:0.0004110392187911493, uniform:0.00016022517689692943
# Iteration 42.
# # of particles to sample:21, stratum length:0.0004051980451301139, uniform:7.352375244068007e-05
# Iteration 43.
# # of particles to sample:16, stratum length:0.00040545093605949697, uniform:0.00027668835264331947
# Iteration 44.
# # of particles to sample:16, stratum length:0.0004180864746016735, uniform:0.0002695764466810468
# Iteration 45.
# # of particles to sample:32, stratum length:0.0005340972944583054, uniform:0.0004966190044247373
# Iteration 46.
# # of particles to sample:13, stratum length:0.0004215018052075884, uniform:0.0002927175975520818
# Iteration 47.
# # of particles to sample:16, stratum length:0.0004978381282006152, uniform:0.0003814965109544423
# Iteration 48.
# # of particles to sample:30, stratum length:0.0005549601581889679, uniform:0.0005119445100133137
# Iteration 49.
# # of particles to sample:11, stratum length:0.000469007092798043, uniform:0.00022551389144523544
# Iteration 50.
# # of particles to sample:19, stratum length:0.000491107650442558, uniform:0.00040754257953194023
# Iteration 51.
# # of particles to sample:20, stratum length:0.0004938593740586303, uniform:0.0002894522676330936
# Iteration 52.
# # of particles to sample:24, stratum length:0.0005236725238730437, uniform:0.0002906408021417546
# Iteration 53.
# # of particles to sample:25, stratum length:0.0005157061021141514, uniform:0.00040308490522740227
# Iteration 54.
# # of particles to sample:26, stratum length:0.0005135056918562761, uniform:0.00033620014235908154
# Iteration 55.
# # of particles to sample:28, stratum length:0.0005467562920005456, uniform:0.0003456615474486144
# Iteration 56.
# # of particles to sample:31, stratum length:0.0006415311616905676, uniform:0.0002744843435597629
# Iteration 57.
# # of particles to sample:17, stratum length:0.0006362632146317365, uniform:0.0002666377886357577
# Iteration 58.
# # of particles to sample:13, stratum length:0.0005673528984168368, uniform:0.00033393839094845236
# Iteration 59.
# # of particles to sample:12, stratum length:0.0005245323875158614, uniform:6.584479781483782e-05
# Iteration 60.
# # of particles to sample:22, stratum length:0.0005866607324937253, uniform:0.0003897540570741307
# Iteration 61.
# # of particles to sample:17, stratum length:0.0005883731175982048, uniform:0.0003916094032847707
# Iteration 62.
# # of particles to sample:9, stratum length:0.0005411439535020965, uniform:0.000200462879378898
# Iteration 63.
# # of particles to sample:32, stratum length:0.0006530217517665501, uniform:0.0006367640756657254
# Iteration 64.
# # of particles to sample:15, stratum length:0.0006227903906463522, uniform:0.0006221138028879889
# Iteration 65.
# # of particles to sample:48, stratum length:0.0014472635589980873, uniform:0.0005416239256604281
# Iteration 66.
# # of particles to sample:48, stratum length:0.0016682631871888785, uniform:0.00027152029261185036
# Iteration 67.
# # of particles to sample:27, stratum length:0.0006566331495512098, uniform:0.00038482321708447703
# Iteration 68.
# # of particles to sample:12, stratum length:0.0003899275897828156, uniform:0.00018130388739266926
# Iteration 69.
# # of particles to sample:12, stratum length:0.0005686032781636355, uniform:0.0002956497547326401
# Iteration 70.
# # of particles to sample:24, stratum length:0.0007603000415393702, uniform:0.0006878180216732965
# Iteration 71.
# # of particles to sample:11, stratum length:0.0005555201497386189, uniform:4.168314215413161e-05
# Iteration 72.
# # of particles to sample:23, stratum length:0.0007695043324135938, uniform:0.0006054117808885184
# Iteration 73.
# # of particles to sample:27, stratum length:0.000806619412212392, uniform:0.0005332136883745877
# Iteration 74.
# # of particles to sample:11, stratum length:0.0007281783071368561, uniform:5.108018154310605e-05
# Iteration 75.
# # of particles to sample:12, stratum length:0.0007679493988195858, uniform:0.0003194202202665682
# Iteration 76.
# # of particles to sample:31, stratum length:0.0008201599541480083, uniform:0.0005286528266781486
# Iteration 77.
# # of particles to sample:30, stratum length:0.0008459727013749144, uniform:4.841647652865476e-05
# Iteration 78.
# # of particles to sample:29, stratum length:0.0008944834442897618, uniform:0.00047494381817595583
# Iteration 79.
# # of particles to sample:9, stratum length:0.0007857691229366489, uniform:0.00015291227878410466
# Iteration 80.
# # of particles to sample:28, stratum length:0.0010382861263336176, uniform:0.0010012857812865116
# Iteration 81.
# # of particles to sample:6, stratum length:0.0006387643068695926, uniform:0.00025572913723965183
# Iteration 82.
# # of particles to sample:7, stratum length:0.0005947873902265866, uniform:0.0003382538837411733
# Iteration 83.
# # of particles to sample:11, stratum length:0.0009709618413716724, uniform:0.0004215936557171483
# Iteration 84.
# # of particles to sample:25, stratum length:0.0011918424906986783, uniform:0.0007230952241032711
# Iteration 85.
# # of particles to sample:4, stratum length:0.0009592082227307162, uniform:0.0004595126905506844
# Iteration 86.
# # of particles to sample:23, stratum length:0.0013706053688923366, uniform:0.0010874590373388421
# Iteration 87.
# # of particles to sample:6, stratum length:0.0007481597550561127, uniform:0.0006456061593418219
# Iteration 88.
# # of particles to sample:6, stratum length:0.0010310925758314012, uniform:0.00012683524918287003
# Iteration 89.
# # of particles to sample:20, stratum length:0.0015293241039563996, uniform:0.0005179592246341237
# Iteration 90.
# # of particles to sample:5, stratum length:0.0010615048777724038, uniform:0.00041418165497580976
# Iteration 91.
# # of particles to sample:8, stratum length:0.001127930377958106, uniform:0.0008487539336674956
# Iteration 92.
# # of particles to sample:5, stratum length:0.0008373916111328504, uniform:0.0005408933647020278
# Iteration 93.
# # of particles to sample:5, stratum length:0.0009174664160243849, uniform:0.0004770730628399747
# Iteration 94.
# # of particles to sample:5, stratum length:0.001482837889431733, uniform:0.0004693866075392779
# Iteration 95.
# # of particles to sample:4, stratum length:0.0012976891760474473, uniform:0.001065342454424567
# Iteration 96.
# # of particles to sample:4, stratum length:0.001184114603019933, uniform:0.0002759039343555536
# Iteration 97.
# # of particles to sample:5, stratum length:0.0014194704405724747, uniform:2.70692169118946e-06
# Iteration 98.
# # of particles to sample:16, stratum length:0.0014952604489308651, uniform:0.001331359905764823
# Iteration 99.
# # of particles to sample:2, stratum length:0.0012808483208706966, uniform:0.0007120851329999107
# Iteration 100.
# # of particles to sample:18, stratum length:0.0014512690242725686, uniform:0.00026598976097494837
# Iteration 101.
# # of particles to sample:18, stratum length:0.0014699319350600594, uniform:0.0005234914690233798
# Iteration 102.
# # of particles to sample:3, stratum length:0.0014774019233192862, uniform:0.0009101521493354208
# Iteration 103.
# # of particles to sample:27, stratum length:0.0015334694685365498, uniform:0.0002483238893385711
# Iteration 104.
# # of particles to sample:27, stratum length:0.0015346564639474776, uniform:0.00014003468929368857
# Iteration 105.
# # of particles to sample:37, stratum length:0.0017980319032913953, uniform:0.0017083083967188806
# Iteration 106.
# # of particles to sample:12, stratum length:0.001464855876617094, uniform:0.0010951132563703078
# Iteration 107.
# # of particles to sample:5, stratum length:0.001233390458543999, uniform:0.0003856942463238714
# Iteration 108.
# # of particles to sample:8, stratum length:0.0013091319742641625, uniform:0.0002970975616215629
# Iteration 109.
# # of particles to sample:36, stratum length:0.0018300706726298002, uniform:0.0012071967795181566
# Iteration 110.
# # of particles to sample:4, stratum length:0.0009839906876926564, uniform:0.0009460200285274642
# Iteration 111.
# # of particles to sample:5, stratum length:0.0010390679798492816, uniform:0.0009805162598594387
# Iteration 112.
# # of particles to sample:15, stratum length:0.00165029734865673, uniform:0.00030055885714543745
# Iteration 113.
# # of particles to sample:8, stratum length:0.0009209689051035961, uniform:0.0008203068254253861
# Iteration 114.
# # of particles to sample:8, stratum length:0.0009468318581696477, uniform:0.00045736164130365096
# Iteration 115.
# # of particles to sample:7, stratum length:0.0009259461731687733, uniform:0.0003883109757545986
# Iteration 116.
# # of particles to sample:7, stratum length:0.0008887401029423639, uniform:0.0008773097488310502
# Iteration 117.
# # of particles to sample:10, stratum length:0.0013162417724496378, uniform:0.0009315722081876443
# Iteration 118.
# # of particles to sample:6, stratum length:0.0012371314288536807, uniform:0.0011325899669618377
# Iteration 119.
# # of particles to sample:11, stratum length:0.0013932723331227359, uniform:0.001230655281127367
# Iteration 120.
# # of particles to sample:9, stratum length:0.0016383761282285586, uniform:3.5798894496289296e-06
# Iteration 121.
# # of particles to sample:18, stratum length:0.0017839241667974288, uniform:0.0006163582001955132
# Iteration 122.
# # of particles to sample:29, stratum length:0.0017428007171867163, uniform:0.0010212085468685617
# Iteration 123.
# # of particles to sample:4, stratum length:0.0011333566790647975, uniform:0.0010982301177737946
# Iteration 124.
# # of particles to sample:3, stratum length:0.001296799221433829, uniform:2.4141796836594007e-05
# Iteration 125.
# # of particles to sample:32, stratum length:0.0020087995287480756, uniform:0.0005903521894596992
# Iteration 126.
# # of particles to sample:5, stratum length:0.0009144467649270658, uniform:0.0006163798947179994
# Iteration 127.
# # of particles to sample:11, stratum length:0.0017948225087586886, uniform:0.0006972714394476788
# Iteration 128.
# # of particles to sample:15, stratum length:0.0017775839568091817, uniform:0.0008493169503998893
# Iteration 129.
# # of particles to sample:5, stratum length:0.0015499006369590843, uniform:0.0014522371906970084
# Iteration 130.
# # of particles to sample:4, stratum length:0.001351005846062918, uniform:3.969672012547422e-05
# Iteration 131.
# # of particles to sample:28, stratum length:0.0018528421871338366, uniform:0.001603726529650821
# Iteration 132.
# # of particles to sample:3, stratum length:0.00147731191767734, uniform:0.0009186799829468988
# Iteration 133.
# # of particles to sample:11, stratum length:0.0017110590750802632, uniform:0.0010130437409405827
# Iteration 134.
# # of particles to sample:27, stratum length:0.0016647518804055548, uniform:0.000713387285168882
# Iteration 135.
# # of particles to sample:23, stratum length:0.0015740483162532302, uniform:0.0005607782349684805
# Iteration 136.
# # of particles to sample:28, stratum length:0.0014263278959037833, uniform:0.0013695884483030843
# Iteration 137.
# # of particles to sample:20, stratum length:0.001695914944842265, uniform:0.001102597078493433
# Iteration 138.
# # of particles to sample:5, stratum length:0.0014183612402799888, uniform:0.0011399132690697701
# Iteration 139.
# # of particles to sample:4, stratum length:0.0013356270714485028, uniform:0.00124757389268442
# Iteration 140.
# # of particles to sample:4, stratum length:0.0014329454086411254, uniform:7.44886405623881e-05
# Iteration 141.
# # of particles to sample:16, stratum length:0.0015632572061909896, uniform:0.00011474581021536027
# Iteration 142.
# # of particles to sample:27, stratum length:0.0014214668317789148, uniform:0.0007400930926909044
# Iteration 143.
# # of particles to sample:25, stratum length:0.0012064710933634621, uniform:0.00110693334790036
# Iteration 144.
# # of particles to sample:5, stratum length:0.0009368849317354042, uniform:0.00010332608637054453
# Iteration 145.
# # of particles to sample:4, stratum length:0.0010322952595582544, uniform:0.0010023904443401553
# Iteration 146.
# # of particles to sample:4, stratum length:0.0010050376521602703, uniform:0.000879570640978858
# Iteration 147.
# # of particles to sample:5, stratum length:0.0011356221526057123, uniform:0.0008630695437625859
# Iteration 148.
# # of particles to sample:5, stratum length:0.0012268558223984863, uniform:0.0010262398520703938
# Iteration 149.
# # of particles to sample:9, stratum length:0.0015825616905251146, uniform:0.0008325521844940325
# Iteration 150.
# # of particles to sample:5, stratum length:0.0012764564015167919, uniform:2.1952557582977747e-05
# Iteration 151.
# # of particles to sample:4, stratum length:0.0011542306497754683, uniform:0.0005809674722693462
# Iteration 152.
# # of particles to sample:25, stratum length:0.001247054575136875, uniform:0.00036163829894748196
# Iteration 153.
# # of particles to sample:24, stratum length:0.0011747566167613335, uniform:0.0006419484312130889
# Iteration 154.
# # of particles to sample:23, stratum length:0.00146551497178776, uniform:0.0009206514774754405
# Iteration 155.
# # of particles to sample:26, stratum length:0.001285561048354073, uniform:0.0007021609606127872
# Iteration 156.
# # of particles to sample:5, stratum length:0.0007515177755665987, uniform:0.0003836792830200872
# Iteration 157.
# # of particles to sample:5, stratum length:0.000819527924398162, uniform:0.0004798693217230867
# Iteration 158.
# # of particles to sample:29, stratum length:0.002135661587828802, uniform:0.0006240895803515347
# Iteration 159.
# # of particles to sample:15, stratum length:0.0011409239824444306, uniform:1.092507903859044e-05
# Iteration 160.
# # of particles to sample:21, stratum length:0.0012295902248329034, uniform:0.0010165895174753209
# Iteration 161.
# # of particles to sample:15, stratum length:0.0005064063432486559, uniform:0.00038495111920214666
# Iteration 162.
# # of particles to sample:8, stratum length:0.0004428947624196549, uniform:0.00036664205579461776
# Iteration 163.
# # of particles to sample:14, stratum length:0.000676041971623703, uniform:0.000452711261783793
# Iteration 164.
# # of particles to sample:9, stratum length:0.0005259698789159428, uniform:0.0003968027175710158
# Iteration 165.
# # of particles to sample:15, stratum length:0.000808901232984623, uniform:0.0005486372980917013
# Iteration 166.
# # of particles to sample:8, stratum length:0.0005142030260685362, uniform:0.000255806634296629
# Iteration 167.
# # of particles to sample:21, stratum length:0.0011386135869880134, uniform:0.0003938990232110957
# Iteration 168.
# # of particles to sample:9, stratum length:0.0005481340464380921, uniform:0.0003567092920240254
# Iteration 169.
# # of particles to sample:10, stratum length:0.0005646013087766171, uniform:0.0005329651543899435
# Iteration 170.
# # of particles to sample:11, stratum length:0.000628585607679923, uniform:0.00021157003051521035
# Iteration 171.
# # of particles to sample:12, stratum length:0.0008014546392177264, uniform:9.268797254166308e-05
# Iteration 172.
# # of particles to sample:7, stratum length:0.0006722327521093038, uniform:3.7174729368998405e-05
# Iteration 173.
# # of particles to sample:41, stratum length:0.004154253614487487, uniform:0.003021368362529916
# Iteration 174.
# # of particles to sample:19, stratum length:0.0014201938225199137, uniform:0.0005091325001737244
# Iteration 175.
# # of particles to sample:10, stratum length:0.0012808223180678841, uniform:2.7846114351972787e-05
# Iteration 176.
# # of particles to sample:13, stratum length:0.0012445926840064464, uniform:0.00048422410199917013
# Iteration 177.
# # of particles to sample:8, stratum length:0.0011331263708033066, uniform:0.00096069576686708
# Iteration 178.
# # of particles to sample:4, stratum length:0.0011061343183389211, uniform:2.6315981260491578e-05
# Iteration 179.
# # of particles to sample:6, stratum length:0.0009217959667011306, uniform:0.0003689482206112265
# Iteration 180.
# # of particles to sample:6, stratum length:0.0009354946419042103, uniform:0.00011846055508127482
# Iteration 181.
# # of particles to sample:6, stratum length:0.0009491452729730817, uniform:0.0006518515328621952
# Iteration 182.
# # of particles to sample:7, stratum length:0.000995122288559028, uniform:8.005017067022626e-05
# Iteration 183.
# # of particles to sample:8, stratum length:0.0010673212148033994, uniform:0.000505844782378281
# Iteration 184.
# # of particles to sample:10, stratum length:0.0011513361872508294, uniform:0.0006894718156023962
# Iteration 185.
# # of particles to sample:12, stratum length:0.0013715361841236358, uniform:0.00036713867170141436
# Iteration 186.
# # of particles to sample:6, stratum length:0.001135260896136797, uniform:0.0007094048626023629
# Iteration 187.
# # of particles to sample:24, stratum length:0.001879319852609063, uniform:0.00029775802193880485
# Iteration 188.
# # of particles to sample:27, stratum length:0.00275041289141395, uniform:0.002420142479600408
# Iteration 189.
# # of particles to sample:12, stratum length:0.0008218611326357461, uniform:0.00015011825334552303
# Iteration 190.
# # of particles to sample:9, stratum length:0.0008041027967419822, uniform:2.877521703131847e-05
# Iteration 191.
# # of particles to sample:9, stratum length:0.0008138271071946477, uniform:0.00048225168679928606
# Iteration 192.
# # of particles to sample:10, stratum length:0.0008438236092056806, uniform:0.0006620497166748511
# Iteration 193.
# # of particles to sample:11, stratum length:0.0008743116207613825, uniform:0.0007276817544036719
# Iteration 194.
# # of particles to sample:14, stratum length:0.0009361842791790909, uniform:0.00043629545301158344
# Iteration 195.
# # of particles to sample:14, stratum length:0.0009617984482793484, uniform:0.00046270991705960903
# Iteration 196.
# # of particles to sample:14, stratum length:0.0010098090163569936, uniform:0.0009278740610043369
# Iteration 197.
# # of particles to sample:10, stratum length:0.0010370293982155266, uniform:0.0005048071584646076
# Iteration 198.
# # of particles to sample:11, stratum length:0.001104997135770386, uniform:0.0007685050094245819
# Iteration 199.
# # of particles to sample:12, stratum length:0.0011219539019187495, uniform:0.00036891262555060697
# Iteration 200.
# # of particles to sample:15, stratum length:0.0011870656780499447, uniform:0.0010474543078239293
# Iteration 201.
# # of particles to sample:11, stratum length:0.001203750434562875, uniform:0.000620495053289867
# Iteration 202.
# # of particles to sample:3, stratum length:0.0011464592066877844, uniform:0.0003240029444032153
# Iteration 203.
# # of particles to sample:15, stratum length:0.001734303856336289, uniform:0.001107531000158434
# Iteration 204.
# # of particles to sample:11, stratum length:0.002145385510657807, uniform:0.0019446160019510163
# Iteration 205.
# # of particles to sample:7, stratum length:0.001081159579557739, uniform:0.0005067588155641605
# Iteration 206.
# # of particles to sample:3, stratum length:0.0009435660022385798, uniform:0.0005909437189736031
# Iteration 207.
# # of particles to sample:7, stratum length:0.0010363818794718984, uniform:0.0006018379539258808
# Iteration 208.
# # of particles to sample:6, stratum length:0.0010360980089425082, uniform:0.0005146165365068231
# Iteration 209.
# # of particles to sample:12, stratum length:0.0015524748803386207, uniform:0.0010457942231588942
# Iteration 210.
# # of particles to sample:4, stratum length:0.0009841628855268036, uniform:0.0008495423261719176
# Iteration 211.
# # of particles to sample:4, stratum length:0.001302758205067293, uniform:0.001167273958996303
# Iteration 212.
# # of particles to sample:21, stratum length:0.0028038232736891317, uniform:0.0016679380123036395
# Iteration 213.
# # of particles to sample:9, stratum length:0.0013641431121621658, uniform:3.8349333093061856e-05
# Iteration 214.
# # of particles to sample:7, stratum length:0.0007472996526435747, uniform:0.0006329886965209464
# Iteration 215.
# # of particles to sample:7, stratum length:0.0005708954003766365, uniform:0.0005390406671976564
# Iteration 216.
# # of particles to sample:8, stratum length:0.001053900671789216, uniform:3.7809737636377005e-05
# Iteration 217.
# # of particles to sample:6, stratum length:0.0007308109685690503, uniform:0.0001188081246883096
# Iteration 218.
# # of particles to sample:7, stratum length:0.0009727155514585821, uniform:0.0004696328632317542
# Iteration 219.
# # of particles to sample:4, stratum length:0.0009243924199591117, uniform:0.0002264894059708021
# Iteration 220.
# # of particles to sample:10, stratum length:0.0012024512419429088, uniform:0.00038393636081711857
# Iteration 221.
# # of particles to sample:5, stratum length:0.0011051072126925612, uniform:0.0007635791501534754
# Iteration 222.
# # of particles to sample:10, stratum length:0.0012295786681107725, uniform:4.4953085277864104e-05
# Iteration 223.
# # of particles to sample:9, stratum length:0.0012200543750982911, uniform:9.481701253299329e-05
# Iteration 224.
# # of particles to sample:10, stratum length:0.001299666757785203, uniform:0.0005003939734447217
# Iteration 225.
# # of particles to sample:10, stratum length:0.0014142016754562703, uniform:0.00010838347478181309
# Iteration 226.
# # of particles to sample:10, stratum length:0.001483911390384028, uniform:0.0013686479228754436
# Iteration 227.
# # of particles to sample:8, stratum length:0.0015389308535730124, uniform:0.0010119095325895927
# Iteration 228.
# # of particles to sample:11, stratum length:0.0016300576752893948, uniform:0.0012108210385510132
# Iteration 229.
# # of particles to sample:7, stratum length:0.002014216543117139, uniform:0.0007265540249441409
# Iteration 230.
# # of particles to sample:6, stratum length:0.0016674716359756671, uniform:0.00025078855975740563
# Iteration 231.
# # of particles to sample:6, stratum length:0.0016699176955369552, uniform:0.0006050065415556377
# Iteration 232.
# # of particles to sample:7, stratum length:0.00195747112388464, uniform:0.000816767247468433
# Iteration 233.
# # of particles to sample:7, stratum length:0.0018719644237453275, uniform:0.0006090364690720337
# Iteration 234.
# # of particles to sample:7, stratum length:0.0018838432334728188, uniform:0.001137029398382716
# Iteration 235.
# # of particles to sample:5, stratum length:0.002055506114637946, uniform:0.0006973044497039898
# Iteration 236.
# # of particles to sample:9, stratum length:0.0020831523023507035, uniform:0.0012728393687702307
# Iteration 237.
# # of particles to sample:10, stratum length:0.0020138422723150603, uniform:0.0007509395745531279
# Iteration 238.
# # of particles to sample:10, stratum length:0.0024314482214783705, uniform:0.0014276433116924628
# Iteration 239.
# # of particles to sample:2, stratum length:0.001904720774818712, uniform:0.0017455514232930076
# Iteration 240.
# # of particles to sample:3, stratum length:0.0018724129812489876, uniform:0.0015658072532148816
# Iteration 241.
# # of particles to sample:2, stratum length:0.0016866452984247082, uniform:0.0005038661275176626
# Iteration 242.
# # of particles to sample:10, stratum length:0.002380898261339962, uniform:0.00019915865660179334
# Iteration 243.
# # of particles to sample:11, stratum length:0.002373970412034185, uniform:0.0005724090667360933
# Iteration 244.
# # of particles to sample:9, stratum length:0.0024215667349466617, uniform:0.0009617187261821158
# Iteration 245.
# # of particles to sample:4, stratum length:0.0018705860336327216, uniform:5.9166575496500195e-05
# Iteration 246.
# # of particles to sample:10, stratum length:0.0024249235220503906, uniform:0.001115568072750128
# Iteration 247.
# # of particles to sample:3, stratum length:0.0022609226326445976, uniform:0.0020157679659684215
# Iteration 248.
# # of particles to sample:4, stratum length:0.002304965304110821, uniform:0.0014675908806853495
# Iteration 249.
# # of particles to sample:13, stratum length:0.0025019553916253174, uniform:0.0010988874888365056
# Iteration 250.
# # of particles to sample:8, stratum length:0.0023680595382043514, uniform:0.0015216197861414992
# Iteration 251.
# # of particles to sample:3, stratum length:0.0023371818436367037, uniform:0.00045580236049459457
# Iteration 252.
# # of particles to sample:8, stratum length:0.002387909280016619, uniform:0.0006247098229197757
# Iteration 253.
# # of particles to sample:9, stratum length:0.0024368309411571644, uniform:0.002235072348180452
# Iteration 254.
# # of particles to sample:5, stratum length:0.0024305853904009397, uniform:0.001034914101376441
# Iteration 255.
# # of particles to sample:12, stratum length:0.0025779008715767905, uniform:0.0025075186621084434
# Iteration 256.
# # of particles to sample:3, stratum length:0.0017783619456336558, uniform:0.001416839683075919
# Iteration 257.
# # of particles to sample:10, stratum length:0.0024642635160124927, uniform:0.0005158799520659646
# Iteration 258.
# # of particles to sample:4, stratum length:0.0023660397213131823, uniform:0.0022621220099106848
# Iteration 259.
# # of particles to sample:2, stratum length:0.0021890860058163754, uniform:0.0017600063104866472
# Iteration 260.
# # of particles to sample:11, stratum length:0.002665767125313226, uniform:0.0011040266693325476
# Iteration 261.
# # of particles to sample:8, stratum length:0.002621762290874946, uniform:0.001440496695690859
# Iteration 262.
# # of particles to sample:3, stratum length:0.0023169289881974325, uniform:0.001350440644738801
# Iteration 263.
# # of particles to sample:12, stratum length:0.0025824502094778812, uniform:0.0013610962441171501
# Iteration 264.
# # of particles to sample:33, stratum length:0.0024341750356139196, uniform:0.00019091590601422512
# Iteration 265.
# # of particles to sample:33, stratum length:0.002104365131412379, uniform:0.00014111224315850775
# Iteration 266.
# # of particles to sample:2, stratum length:0.001780702249242758, uniform:0.0014315275273028031
# Iteration 267.
# # of particles to sample:33, stratum length:0.0019085338691616687, uniform:0.0001304223237032013
# Iteration 268.
# # of particles to sample:4, stratum length:0.001741132712451166, uniform:0.001414373494315061
# Iteration 269.
# # of particles to sample:4, stratum length:0.0016977865972584699, uniform:0.0004307000515880152
# Iteration 270.
# # of particles to sample:34, stratum length:0.0019290634219152915, uniform:0.0019069689458612912
# Iteration 271.
# # of particles to sample:32, stratum length:0.0016524745781017719, uniform:0.0010400031395234508
# Iteration 272.
# # of particles to sample:3, stratum length:0.0012061010686966087, uniform:0.00023863652785898224
# Iteration 273.
# # of particles to sample:31, stratum length:0.0014269615584260882, uniform:0.0008114980452781105
# Iteration 274.
# # of particles to sample:5, stratum length:0.0011726841214735125, uniform:0.0011429902934088762
# Iteration 275.
# # of particles to sample:5, stratum length:0.0010867463623361311, uniform:0.00028645347120855025
# Iteration 276.
# # of particles to sample:37, stratum length:0.001902545330727596, uniform:0.0016714673516822712
# Iteration 277.
# # of particles to sample:6, stratum length:0.0010436746844303135, uniform:0.00013733249638788026
# Iteration 278.
# # of particles to sample:6, stratum length:0.001198993478435179, uniform:0.0003494062093725397
# Iteration 279.
# # of particles to sample:3, stratum length:0.0011264220489647983, uniform:0.0005938775452634036
# Iteration 280.
# # of particles to sample:5, stratum length:0.001214793455928606, uniform:0.00046925917205107817
# Iteration 281.
# # of particles to sample:13, stratum length:0.0016995265857080583, uniform:0.0002701569051286749
# Iteration 282.
# # of particles to sample:3, stratum length:0.001021678710905107, uniform:9.984836729655183e-05
# Iteration 283.
# # of particles to sample:4, stratum length:0.00141336960452576, uniform:0.00022002995969457414
# Iteration 284.
# # of particles to sample:10, stratum length:0.0015355684306849963, uniform:0.0012954631551898887
# Iteration 285.
# # of particles to sample:3, stratum length:0.0012573924996161204, uniform:0.0010707641871553965
# Iteration 286.
# # of particles to sample:4, stratum length:0.0013111166070654936, uniform:0.0010180636399469093
# Iteration 287.
# # of particles to sample:32, stratum length:0.0015716911228603968, uniform:9.423074140231938e-05
# Iteration 288.
# # of particles to sample:10, stratum length:0.0016597202373128614, uniform:0.00040009392847641215
# Iteration 289.
# # of particles to sample:3, stratum length:0.0012351800638296937, uniform:0.0008881237837846722
# Iteration 290.
# # of particles to sample:6, stratum length:0.0014029369009361684, uniform:0.001393034755983822
# Iteration 291.
# # of particles to sample:6, stratum length:0.0013996938443253957, uniform:0.0006804255244362764
# Iteration 292.
# # of particles to sample:8, stratum length:0.0015629567542201782, uniform:0.0001721721293236711
# Iteration 293.
# # of particles to sample:12, stratum length:0.0016830230542122196, uniform:0.00039629329435519016
# Iteration 294.
# # of particles to sample:10, stratum length:0.002259743891309898, uniform:0.0007096302024677302
# Iteration 295.
# # of particles to sample:2, stratum length:0.0014433089474046234, uniform:0.0009272116744085149
# Iteration 296.
# # of particles to sample:4, stratum length:0.0020196166931109, uniform:0.0013934568129435122
# Iteration 297.
# # of particles to sample:6, stratum length:0.002097944027843634, uniform:0.00018624249670564998
# Iteration 298.
# # of particles to sample:10, stratum length:0.002120738548089663, uniform:7.333520199625268e-05
# Iteration 299.
# # of particles to sample:9, stratum length:0.0024121902619253983, uniform:0.0009871448997809994
# Iteration 300.
# # of particles to sample:7, stratum length:0.002372087111519348, uniform:0.0010601429964323963
# Iteration 301.
# # of particles to sample:8, stratum length:0.0019758634622521424, uniform:0.001964787937361079
# Iteration 302.
# # of particles to sample:2, stratum length:0.0016485714250046013, uniform:0.00016010487491141005
# Iteration 303.
# # of particles to sample:7, stratum length:0.001607047521002594, uniform:0.0004691363488609297
# Iteration 304.
# # of particles to sample:9, stratum length:0.0016369227925528943, uniform:0.0014712709827642203
# Iteration 305.
# # of particles to sample:9, stratum length:0.001697885217766054, uniform:0.0011536019078141572
# Iteration 306.
# # of particles to sample:52, stratum length:0.003099271292475635, uniform:0.003050171948323524
# Iteration 307.
# # of particles to sample:9, stratum length:0.0009014068472736818, uniform:0.0001672673883754879
# Iteration 308.
# # of particles to sample:4, stratum length:0.0009001131046846772, uniform:0.0004439458186485406
# Iteration 309.
# # of particles to sample:9, stratum length:0.000992266167005244, uniform:0.0008950853770444035
# Iteration 310.
# # of particles to sample:9, stratum length:0.0011210596838203178, uniform:0.00036498469177219454
# Iteration 311.
# # of particles to sample:11, stratum length:0.002325382623879327, uniform:0.00017658432062737602
# Iteration 312.
# # of particles to sample:5, stratum length:0.0010329856513961015, uniform:0.00014955262459669674
# Iteration 313.
# # of particles to sample:5, stratum length:0.0012193218093130846, uniform:0.0004894741237063041
# Iteration 314.
# # of particles to sample:5, stratum length:0.0013184316732219369, uniform:2.7096992532180904e-05
# Iteration 315.
# # of particles to sample:9, stratum length:0.00172072618361288, uniform:0.0017079883423226471
# Iteration 316.
# # of particles to sample:2, stratum length:0.0014070870746790542, uniform:1.829244976906609e-05
# Iteration 317.
# # of particles to sample:7, stratum length:0.0017006372749622056, uniform:0.0014303238090375536
# Iteration 318.
# # of particles to sample:4, stratum length:0.0016142515135025466, uniform:0.0008563640366814696
# Iteration 319.
# # of particles to sample:6, stratum length:0.0016044832821897747, uniform:0.0005836056585940251
# Iteration 320.
# # of particles to sample:7, stratum length:0.0015980000561670417, uniform:0.0007762772084726743
# Iteration 321.
# # of particles to sample:7, stratum length:0.0016480258475645663, uniform:0.0001323232559503507
# Iteration 322.
# # of particles to sample:12, stratum length:0.0018364349651377443, uniform:0.0007419847827598973
# Iteration 323.
# # of particles to sample:7, stratum length:0.0018132117025285537, uniform:0.0009782654343552378
# Iteration 324.
# # of particles to sample:11, stratum length:0.00195004209578003, uniform:0.0014976251378811167
# Iteration 325.
# # of particles to sample:12, stratum length:0.002203756755469387, uniform:0.0015597919299621685
# Iteration 326.
# # of particles to sample:20, stratum length:0.003016152753443276, uniform:0.00012201702509551415
# Iteration 327.
# # of particles to sample:3, stratum length:0.0024264386509362393, uniform:0.00047973339066094135
# Iteration 328.
# # of particles to sample:13, stratum length:0.002797329884954782, uniform:0.0007110390011150911
# Iteration 329.
# # of particles to sample:2, stratum length:0.0018836317360588024, uniform:0.00015062056165436689
# Iteration 330.
# # of particles to sample:2, stratum length:0.002198710626774482, uniform:0.00046433717996025877
# Iteration 331.
# # of particles to sample:5, stratum length:0.0028985064004549573, uniform:0.001271070762523555
# Iteration 332.
# # of particles to sample:15, stratum length:0.0029485185181226973, uniform:0.0019696025327804556
# Iteration 333.
# # of particles to sample:15, stratum length:0.0030703993767581092, uniform:0.0026184911406034427
# Iteration 334.
# # of particles to sample:28, stratum length:0.0041448621856456265, uniform:0.0013725833433325695
# Iteration 335.
# # of particles to sample:21, stratum length:0.0032793417535085766, uniform:0.002999797573690804
# Iteration 336.
# # of particles to sample:2, stratum length:0.00200999197944303, uniform:0.0015377337471799077
# Iteration 337.
# # of particles to sample:4, stratum length:0.002146168552573219, uniform:0.001725807783001683
# Iteration 338.
# # of particles to sample:7, stratum length:0.002163732941707991, uniform:0.0003617961205703432
# Iteration 339.
# # of particles to sample:7, stratum length:0.0019230931664622343, uniform:0.001261567464221337
# Iteration 340.
# # of particles to sample:3, stratum length:0.00254920746744308, uniform:0.001961370616375176
# Iteration 341.
# # of particles to sample:17, stratum length:0.00234208782356998, uniform:0.0019268689098018666
# Iteration 342.
# # of particles to sample:3, stratum length:0.0014933179197428054, uniform:0.0013908734039923523
# Iteration 343.
# # of particles to sample:3, stratum length:0.001649420025104227, uniform:0.00138716312032831
# Iteration 344.
# # of particles to sample:3, stratum length:0.0018728751185780783, uniform:0.00014609553757140596
# Iteration 345.
# # of particles to sample:19, stratum length:0.002116840604096071, uniform:0.0018250793636029644
# Iteration 346.
# # of particles to sample:18, stratum length:0.0019452729929383796, uniform:0.0007052464967862623
# Iteration 347.
# # of particles to sample:19, stratum length:0.0015700796050570614, uniform:0.0003985534720389574
# Iteration 348.
# # of particles to sample:3, stratum length:0.0020843574466186125, uniform:0.0007263592401976406
# Iteration 349.
# # of particles to sample:4, stratum length:0.002200407600648794, uniform:0.0017285000972543031
# Iteration 350.
# # of particles to sample:9, stratum length:0.002023536777442751, uniform:0.0015308919009224423
# Iteration 351.
# # of particles to sample:6, stratum length:0.00157574229539711, uniform:0.0011794776597650232
# Iteration 352.
# # of particles to sample:6, stratum length:0.0016392573535324558, uniform:0.0004021496252198973
# Iteration 353.
# # of particles to sample:28, stratum length:0.0030159294453547688, uniform:0.0009550951768674724
# Iteration 354.
# # of particles to sample:3, stratum length:0.001874785915253663, uniform:0.0008011820245170349
# Iteration 355.
# # of particles to sample:28, stratum length:0.0034195391112703893, uniform:0.0024367483009039986
# Iteration 356.
# # of particles to sample:27, stratum length:0.003383212250906551, uniform:0.0006481487809932297
# Iteration 357.
# # of particles to sample:34, stratum length:0.002237258648103517, uniform:0.0010209559844486776
# Iteration 358.
# # of particles to sample:54, stratum length:0.003351834864208734, uniform:0.0018446857558544214
# Iteration 359.
# # of particles to sample:56, stratum length:0.0017259191128197982, uniform:0.0007741385096335589
# Iteration 360.
# # of particles to sample:17, stratum length:0.0026837011850891434, uniform:0.001551728854546831
# Iteration 361.
# # of particles to sample:7, stratum length:0.000492115440978046, uniform:0.0003181614246604571
# Iteration 362.
# # of particles to sample:9, stratum length:0.0006572311653123188, uniform:0.0005828488368871223
# Iteration 363.
# # of particles to sample:18, stratum length:0.0006485306384780309, uniform:0.0002516730536356509
# Iteration 364.
# # of particles to sample:20, stratum length:0.0004559335249660015, uniform:0.000285997930318958
# Iteration 365.
# # of particles to sample:13, stratum length:0.0005244615622995335, uniform:0.0002759848226952089
# Iteration 366.
# # of particles to sample:31, stratum length:0.00043897632027110574, uniform:0.0001392505843795964
# Iteration 367.
# # of particles to sample:11, stratum length:0.0003631253967245822, uniform:4.492890603535419e-05
# Iteration 368.
# # of particles to sample:15, stratum length:0.0003890447651064974, uniform:0.00024266931259456107
# Iteration 369.
# # of particles to sample:31, stratum length:0.0004240539435352219, uniform:2.515667874048272e-05
# Iteration 370.
# # of particles to sample:21, stratum length:0.0003714778849746506, uniform:2.792739889013799e-05
# Iteration 371.
# # of particles to sample:26, stratum length:0.0003949837964217006, uniform:4.368935371174766e-05
# Iteration 372.
# # of particles to sample:25, stratum length:0.00039825493875790335, uniform:0.000261729867266201
# Iteration 373.
# # of particles to sample:44, stratum length:0.0009061993112652829, uniform:1.4514444786357117e-05
# Iteration 374.
# # of particles to sample:27, stratum length:0.00032109921054376513, uniform:9.926742925213871e-05
# Iteration 375.
# # of particles to sample:27, stratum length:0.00034076934467719986, uniform:0.0001745765972465871
# Iteration 376.
# # of particles to sample:27, stratum length:0.000350551733563146, uniform:6.547212944996647e-05
# Iteration 377.
# # of particles to sample:30, stratum length:0.00037363961923085896, uniform:7.048783163751061e-05
# Iteration 378.
# # of particles to sample:34, stratum length:0.00038782354550341124, uniform:0.00010029620971995352
# Iteration 379.
# # of particles to sample:26, stratum length:0.0004167426057363179, uniform:0.0003904265524228285
# Iteration 380.
# # of particles to sample:32, stratum length:0.00042218025490464424, uniform:5.088066014458181e-05
# Iteration 381.
# # of particles to sample:30, stratum length:0.0004504284860519052, uniform:0.0003585082459711012
# Iteration 382.
# # of particles to sample:27, stratum length:0.0005635674559500166, uniform:6.583399799939239e-05
# Iteration 383.
# # of particles to sample:22, stratum length:0.0005028797617517302, uniform:0.0002426723094662208
# Iteration 384.
# # of particles to sample:8, stratum length:0.0004308107330625396, uniform:8.035941677576954e-07
# Iteration 385.
# # of particles to sample:28, stratum length:0.0005350424371854303, uniform:0.0003933840419866408
# Iteration 386.
# # of particles to sample:11, stratum length:0.00045322948833013423, uniform:0.0003391313097510314
# Iteration 387.
# # of particles to sample:13, stratum length:0.0005031640970742836, uniform:0.00027865303118853154
# Iteration 388.
# # of particles to sample:49, stratum length:0.001456530316109032, uniform:0.00021613216462820344
# Iteration 389.
# # of particles to sample:18, stratum length:0.0003334664276524174, uniform:7.422405783281638e-05
# Iteration 390.
# # of particles to sample:20, stratum length:0.00035590305630642136, uniform:0.000329576765941025
# Iteration 391.
# # of particles to sample:15, stratum length:0.0003009719476970354, uniform:0.00024882791861645544
# Iteration 392.
# # of particles to sample:21, stratum length:0.00034790742977180896, uniform:0.00025504099994704953
# Iteration 393.
# # of particles to sample:23, stratum length:0.0003686551070093195, uniform:0.00010735908511646939
# Iteration 394.
# # of particles to sample:29, stratum length:0.00046386661150354556, uniform:9.301606941070703e-05
# Iteration 395.
# # of particles to sample:16, stratum length:0.0005802075332170239, uniform:0.0001560584236387989
# Iteration 396.
# # of particles to sample:11, stratum length:0.0005656838268348048, uniform:4.588101871755538e-05
# Iteration 397.
# # of particles to sample:16, stratum length:0.0005268954964790166, uniform:0.0003250073895736578
# Iteration 398.
# # of particles to sample:33, stratum length:0.0007132803248074542, uniform:0.0003125387209370676
# Iteration 399.
# # of particles to sample:15, stratum length:0.000392608381969314, uniform:0.00021706553252991522
# Iteration 400.
# # of particles to sample:15, stratum length:0.00045821265369919834, uniform:0.00010673718075696832
# Iteration 401.
# # of particles to sample:16, stratum length:0.0006240549758139926, uniform:0.0005972274965569577
# Iteration 402.
# # of particles to sample:20, stratum length:0.0006926369210468098, uniform:0.0005730389579088924
# Iteration 403.
# # of particles to sample:15, stratum length:0.0008254485117193355, uniform:0.0004932260252198501
# Iteration 404.
# # of particles to sample:7, stratum length:0.0007973096535575366, uniform:0.0002261565963459731
# Iteration 405.
# # of particles to sample:11, stratum length:0.0007493596123790357, uniform:0.0007467286134697976
# Iteration 406.
# # of particles to sample:10, stratum length:0.0007376230688832219, uniform:0.000531634086898648
# Iteration 407.
# # of particles to sample:25, stratum length:0.0008545548186772152, uniform:0.0007492775631283365
# Iteration 408.
# # of particles to sample:8, stratum length:0.0005006669385600074, uniform:0.00035208351958044914
# Iteration 409.
# # of particles to sample:10, stratum length:0.000635077004970903, uniform:0.00026635043100178433
# Iteration 410.
# # of particles to sample:12, stratum length:0.0006515522120117889, uniform:0.00044685897168770204
# Iteration 411.
# # of particles to sample:15, stratum length:0.0006766265603101898, uniform:0.0002304450355218548
# Iteration 412.
# # of particles to sample:20, stratum length:0.0007568601675040995, uniform:0.00042206384308917473
# Iteration 413.
# # of particles to sample:9, stratum length:0.0007130860775990986, uniform:0.00015069696675634807
# Iteration 414.
# # of particles to sample:11, stratum length:0.0007515696098267841, uniform:0.0002168106857277166
# Iteration 415.
# # of particles to sample:23, stratum length:0.0008258413451972451, uniform:7.880546138563975e-05
# Iteration 416.
# # of particles to sample:6, stratum length:0.0007397133447882379, uniform:0.000696242844125921
# Iteration 417.
# # of particles to sample:36, stratum length:0.000972033128910245, uniform:0.0002484471076234458
# Iteration 418.
# # of particles to sample:7, stratum length:0.0005694465012024121, uniform:0.00041075144396707984
# Iteration 419.
# # of particles to sample:21, stratum length:0.0009225063041443473, uniform:0.000643448441713877
# Iteration 420.
# # of particles to sample:8, stratum length:0.0006277431657299853, uniform:0.0005993279033536319
# Iteration 421.
# # of particles to sample:8, stratum length:0.0008415457697076216, uniform:0.0006925176286397435
# Iteration 422.
# # of particles to sample:31, stratum length:0.0010051537059755124, uniform:0.00015783544422507328
# Iteration 423.
# # of particles to sample:13, stratum length:0.00097797689020043, uniform:0.000915119452537754
# Iteration 424.
# # of particles to sample:18, stratum length:0.0010032792440923639, uniform:7.964818934429363e-05
# Iteration 425.
# # of particles to sample:6, stratum length:0.0009414204152805324, uniform:0.0005238738646300264
# Iteration 426.
# # of particles to sample:10, stratum length:0.0009889141049540492, uniform:0.0001451897621643732
# Iteration 427.
# # of particles to sample:6, stratum length:0.0009617007389404608, uniform:0.0005352403375102824
# Iteration 428.
# # of particles to sample:37, stratum length:0.0011090779372089042, uniform:0.00042799176449514234
# Iteration 429.
# # of particles to sample:25, stratum length:0.0011200573360802405, uniform:0.0009735506544376501
# Iteration 430.
# # of particles to sample:30, stratum length:0.0011345734951794533, uniform:0.0009189218940162077
# Iteration 431.
# # of particles to sample:9, stratum length:0.0008498818711189925, uniform:0.0005845913668181717
# Iteration 432.
# # of particles to sample:8, stratum length:0.0007710505212345457, uniform:0.00013029925576438963
# Iteration 433.
# ...
# Iteration 3909.
# # of particles to sample:17, stratum length:0.0006518849740560866, uniform:5.6635966270748394e-05
# Iteration 3910.
# # of particles to sample:22, stratum length:0.0006708796455675746, uniform:4.093147350070221e-05
# Iteration 3911.
# # of particles to sample:9, stratum length:0.00058067555578391, uniform:0.0001248997882654358
# Iteration 3912.
# # of particles to sample:10, stratum length:0.000585625857759916, uniform:0.00040638472215806005
# Iteration 3913.
# # of particles to sample:10, stratum length:0.0006179536216269282, uniform:0.00035741484943349535
# Iteration 3914.
# # of particles to sample:12, stratum length:0.0006258154092245327, uniform:0.00018306442550895122
# Iteration 3915.
# # of particles to sample:21, stratum length:0.0010756070584063183, uniform:0.001038108408719634
# Iteration 3916.
# # of particles to sample:7, stratum length:0.0007863825984642008, uniform:0.0001318921104557876
# Iteration 3917.
# # of particles to sample:8, stratum length:0.0008567355584591633, uniform:0.00028897221429597606
# Iteration 3918.
# # of particles to sample:16, stratum length:0.001097745226714116, uniform:0.0008781262710735734
# Iteration 3919.
# # of particles to sample:33, stratum length:0.00134631984027925, uniform:0.0009190581893292267
# Iteration 3920.
# # of particles to sample:38, stratum length:0.001145330074942376, uniform:0.00014252654411570274
# Iteration 3921.
# # of particles to sample:34, stratum length:0.000631139081529211, uniform:0.00043834927446348567
# Iteration 3922.
# # of particles to sample:31, stratum length:0.00031691994571687984, uniform:9.256964840450434e-05
# Iteration 3923.
# # of particles to sample:16, stratum length:0.0004712074887436634, uniform:0.0002809575927168661
# Iteration 3924.
# # of particles to sample:28, stratum length:0.00038235350102464207, uniform:0.00037858584110599407
# Iteration 3925.
# # of particles to sample:26, stratum length:0.0002642638726081697, uniform:7.181800868858523e-05
# Iteration 3926.
# # of particles to sample:18, stratum length:0.00036351747043060137, uniform:0.00024143304930790516
# Iteration 3927.
# # of particles to sample:25, stratum length:0.00029880642434472823, uniform:0.00024341797861166515
# Iteration 3928.
# # of particles to sample:27, stratum length:0.00029791186787128047, uniform:0.0002658172331923097
# Iteration 3929.
# # of particles to sample:29, stratum length:0.000308524283437734, uniform:0.00022800393588244162
# Iteration 3930.
# # of particles to sample:26, stratum length:0.000422304307041379, uniform:0.0003060211967408575
# Iteration 3931.
# # of particles to sample:14, stratum length:0.0003636776256078948, uniform:0.00016548652073726042
# Iteration 3932.
# # of particles to sample:34, stratum length:0.0004420906095673277, uniform:0.00020512770613694795
# Iteration 3933.
# # of particles to sample:28, stratum length:0.00036169753632761797, uniform:0.0002659864494142594
# Iteration 3934.
# # of particles to sample:24, stratum length:0.0002881873708921434, uniform:0.00022777416352437655
# Iteration 3935.
# # of particles to sample:22, stratum length:0.00030922145691570415, uniform:0.00011081559795102512
# Iteration 3936.
# # of particles to sample:35, stratum length:0.00046840897780770505, uniform:1.657729920010959e-05
# Iteration 3937.
# # of particles to sample:12, stratum length:0.000352952655484728, uniform:0.00011055365679083695
# Iteration 3938.
# # of particles to sample:17, stratum length:0.00042797106468645836, uniform:0.000152369912162463
# Iteration 3939.
# # of particles to sample:31, stratum length:0.0006857261110008298, uniform:1.9397000896260507e-05
# Iteration 3940.
# # of particles to sample:24, stratum length:0.0007461875688318684, uniform:0.000666158780471436
# Iteration 3941.
# # of particles to sample:22, stratum length:0.0007560185855337464, uniform:0.00043013057741750685
# Iteration 3942.
# # of particles to sample:43, stratum length:0.006009789141218575, uniform:0.0046507623961102125
# Iteration 3943.
# # of particles to sample:25, stratum length:0.0010587949142222544, uniform:0.00030415123540038214
# Iteration 3944.
# # of particles to sample:12, stratum length:0.001115307019574342, uniform:0.00034097815630048024
# Iteration 3945.
# # of particles to sample:4, stratum length:0.0010696325027415821, uniform:0.0005207024158964913
# Iteration 3946.
# # of particles to sample:36, stratum length:0.0012329936135212329, uniform:0.0009426592071487658
# Iteration 3947.
# # of particles to sample:36, stratum length:0.0013398385517111038, uniform:0.00022758586373678558
# Iteration 3948.
# # of particles to sample:39, stratum length:0.001437308536637276, uniform:0.0011397634457345233
# Iteration 3949.
# # of particles to sample:39, stratum length:0.0015342288883120182, uniform:0.0011380082333016437
# Iteration 3950.
# # of particles to sample:39, stratum length:0.001630882143529962, uniform:0.0007663350800382978
# Iteration 3951.
# # of particles to sample:42, stratum length:0.0017236270048319262, uniform:0.0016549942658019622
# Iteration 3952.
# # of particles to sample:42, stratum length:0.0018119940676552771, uniform:0.0015026130874216674
# Iteration 3953.
# # of particles to sample:43, stratum length:0.0018999070364563622, uniform:0.0014863251745650583
# Iteration 3954.
# # of particles to sample:43, stratum length:0.0019853629342311274, uniform:0.001656284408462477
# Iteration 3955.
# # of particles to sample:43, stratum length:0.002070509054861126, uniform:0.00203593569645326
# Iteration 3956.
# # of particles to sample:43, stratum length:0.0021553297146194397, uniform:0.0016181071375389487
# Iteration 3957.
# # of particles to sample:43, stratum length:0.0022398184510233105, uniform:0.00032002012828938613
# Iteration 3958.
# # of particles to sample:44, stratum length:0.00232274172675863, uniform:0.0020920240531436415
# Iteration 3959.
# # of particles to sample:45, stratum length:0.0024041871753801504, uniform:0.00023659162014352851
# Iteration 3960.
# # of particles to sample:45, stratum length:0.0024835320017413385, uniform:0.0022484643658087175
# Iteration 3961.
# # of particles to sample:45, stratum length:0.0025656055094006474, uniform:0.0016450758595042605
# Iteration 3962.
# # of particles to sample:45, stratum length:0.0026713103568465598, uniform:0.0010208674455661933
# Iteration 3963.
# # of particles to sample:42, stratum length:0.003310709281598382, uniform:0.00174011484929271
# Iteration 3964.
# # of particles to sample:35, stratum length:0.0034366173299879626, uniform:0.0017999591873320152
# Iteration 3965.
# # of particles to sample:47, stratum length:0.005223600619674279, uniform:8.732872704363709e-05
# Iteration 3966.
# # of particles to sample:13, stratum length:0.0007768242944178052, uniform:0.000586816284365778
# Iteration 3967.
# # of particles to sample:16, stratum length:0.0007276409516074686, uniform:1.0025770520312828e-05
# Iteration 3968.
# # of particles to sample:8, stratum length:0.0007095401247743559, uniform:0.00028457114877633696
# Iteration 3969.
# # of particles to sample:11, stratum length:0.0007731488872749905, uniform:0.0005151113988929432
# Iteration 3970.
# # of particles to sample:14, stratum length:0.0005489601823907267, uniform:0.0001893652271678997
# Iteration 3971.
# # of particles to sample:14, stratum length:0.0004590216778209737, uniform:0.00041482982103496313
# Iteration 3972.
# # of particles to sample:17, stratum length:0.0007338276319124488, uniform:0.0001794647084739116
# Iteration 3973.
# # of particles to sample:12, stratum length:0.0004983567016237696, uniform:0.00014701855069873619
# Iteration 3974.
# # of particles to sample:11, stratum length:0.0005105246144507363, uniform:0.00016665630264147058
# Iteration 3975.
# # of particles to sample:20, stratum length:0.000792565965949272, uniform:0.0006372188956070164
# Iteration 3976.
# # of particles to sample:9, stratum length:0.00047367359111800755, uniform:0.00017507478380072265
# Iteration 3977.
# # of particles to sample:10, stratum length:0.0005504514784335765, uniform:0.00035909979722250664
# Iteration 3978.
# # of particles to sample:24, stratum length:0.0012310603960042925, uniform:0.0004678434494459092
# Iteration 3979.
# # of particles to sample:7, stratum length:0.0008285205848882609, uniform:2.4566775858715458e-05
# Iteration 3980.
# # of particles to sample:43, stratum length:0.0026075846415346843, uniform:0.00047005461700901747
# Iteration 3981.
# # of particles to sample:15, stratum length:0.000635246001029329, uniform:0.0002083739374763521
# Iteration 3982.
# # of particles to sample:19, stratum length:0.0007375258944786661, uniform:0.0005904596429124267
# Iteration 3983.
# # of particles to sample:19, stratum length:0.0010057628942827745, uniform:0.000624001579136568
# Iteration 3984.
# # of particles to sample:16, stratum length:0.0007698869702327375, uniform:0.00010702420033862507
# Iteration 3985.
# # of particles to sample:16, stratum length:0.0006231849065553868, uniform:0.00022351553062929924
# Iteration 3986.
# # of particles to sample:16, stratum length:0.0005140447880852919, uniform:6.831200457942245e-05
# Iteration 3987.
# # of particles to sample:16, stratum length:0.0005890342194063606, uniform:0.00041372188800448654
# Iteration 3988.
# # of particles to sample:10, stratum length:0.0005158291197426229, uniform:0.000417227598762599
# Iteration 3989.
# # of particles to sample:12, stratum length:0.0005406528420416892, uniform:0.0002506574941532388
# Iteration 3990.
# # of particles to sample:15, stratum length:0.0005975565291627759, uniform:0.00035252151968395755
# Iteration 3991.
# # of particles to sample:16, stratum length:0.000632014183128484, uniform:0.00046130989618279526
# Iteration 3992.
# # of particles to sample:16, stratum length:0.0009415751206848503, uniform:0.0008592589718896486
# Iteration 3993.
# # of particles to sample:9, stratum length:0.0010421437080151722, uniform:0.0010223160336592324
# Iteration 3994.
# # of particles to sample:11, stratum length:0.0007699457074621466, uniform:0.0001431290277688689
# Iteration 3995.
# # of particles to sample:14, stratum length:0.0007701755858277056, uniform:0.00033814900001372306
# Iteration 3996.
# # of particles to sample:13, stratum length:0.0007607539984960216, uniform:0.0006808556672447283
# Iteration 3997.
# # of particles to sample:6, stratum length:0.0006317917549181678, uniform:0.000421870598350287
# Iteration 3998.
# # of particles to sample:12, stratum length:0.0007372080021198565, uniform:0.00018256546523058242
# Iteration 3999.
# # of particles to sample:16, stratum length:0.0008465095983141701, uniform:0.0005863170111315178
# Iteration 4000.
# # of particles to sample:6, stratum length:0.0008007000430728705, uniform:0.00029098236923156173
# Iteration 4001.
# # of particles to sample:14, stratum length:0.0009923711391061044, uniform:0.0007307536161466096
# Iteration 4002.
# # of particles to sample:38, stratum length:0.0026838176579175614, uniform:0.002209496167341517
# Iteration 4003.
# # of particles to sample:4, stratum length:0.0014143953179829763, uniform:0.0011148452583310895
# Iteration 4004.
# # of particles to sample:17, stratum length:0.0009907494450819756, uniform:0.0006584523034873348
# Iteration 4005.
# # of particles to sample:18, stratum length:0.001354445565587317, uniform:0.0007454599589515169
# Iteration 4006.
# # of particles to sample:16, stratum length:0.0016565866376067582, uniform:0.0007836037201989087
# Iteration 4007.
# # of particles to sample:4, stratum length:0.0011269820933675892, uniform:0.000897904383521795
# Iteration 4008.
# # of particles to sample:4, stratum length:0.0013938462507737484, uniform:0.001073380823044704
# Iteration 4009.
# # of particles to sample:8, stratum length:0.001566916595218452, uniform:0.0008253146009241656
# Iteration 4010.
# # of particles to sample:18, stratum length:0.001238340115184385, uniform:0.0009598781148925498
# Iteration 4011.
# # of particles to sample:16, stratum length:0.0011404847041423332, uniform:0.0007346315260616207
# Iteration 4012.
# # of particles to sample:15, stratum length:0.001048808846664865, uniform:0.0002468259685136962
# Iteration 4013.
# # of particles to sample:14, stratum length:0.000735833901176894, uniform:2.1525966885560817e-05
# Iteration 4014.
# # of particles to sample:6, stratum length:0.0008101308602575409, uniform:0.0004014904796170699
# Iteration 4015.
# # of particles to sample:6, stratum length:0.0007335861555692948, uniform:0.00018469123208714056
# Iteration 4016.
# # of particles to sample:20, stratum length:0.0008676366717334984, uniform:0.000504458601575614
# Iteration 4017.
# # of particles to sample:11, stratum length:0.0007341943781506102, uniform:0.00038775590339279215
# Iteration 4018.
# # of particles to sample:13, stratum length:0.0008182116345261778, uniform:0.0006300347232307343
# Iteration 4019.
# # of particles to sample:9, stratum length:0.0007016154658300375, uniform:0.000609814639074707
# Iteration 4020.
# # of particles to sample:10, stratum length:0.0006092880828849287, uniform:0.00024662601449373825
# Iteration 4021.
# # of particles to sample:10, stratum length:0.0006575386396619221, uniform:0.0002222970894805789
# Iteration 4022.
# # of particles to sample:12, stratum length:0.0006833533442996034, uniform:0.0003536646501106509
# Iteration 4023.
# # of particles to sample:10, stratum length:0.0006690314172699814, uniform:0.00014286251950374843
# Iteration 4024.
# # of particles to sample:15, stratum length:0.0006946832869711042, uniform:0.00065842663216333
# Iteration 4025.
# # of particles to sample:13, stratum length:0.0006974408454195156, uniform:0.0005633436811598761
# Iteration 4026.
# # of particles to sample:15, stratum length:0.0007588414538305055, uniform:0.00010815012058755986
# Iteration 4027.
# # of particles to sample:17, stratum length:0.0008854580805035312, uniform:0.00010441991565202212
# Iteration 4028.
# # of particles to sample:17, stratum length:0.0009155712499308204, uniform:0.0007253854951279148
# Iteration 4029.
# # of particles to sample:14, stratum length:0.0008925868347654071, uniform:0.0002262736296506267
# Iteration 4030.
# # of particles to sample:17, stratum length:0.0009087160745046863, uniform:0.0004000690826691327
# Iteration 4031.
# # of particles to sample:5, stratum length:0.0008741501999094155, uniform:0.0002911539821538814
# Iteration 4032.
# # of particles to sample:19, stratum length:0.000948230509589115, uniform:0.0006444275205234429
# Iteration 4033.
# # of particles to sample:17, stratum length:0.0009386568125838217, uniform:0.0009359968998705536
# Iteration 4034.
# # of particles to sample:11, stratum length:0.0009150949925387244, uniform:0.0003133528127246129
# Iteration 4035.
# # of particles to sample:16, stratum length:0.0010645835120000563, uniform:0.00021423540766856938
# Iteration 4036.
# # of particles to sample:23, stratum length:0.001687031623970449, uniform:0.001395997242821844
# Iteration 4037.
# # of particles to sample:6, stratum length:0.0013405902946560468, uniform:0.00026094315721644676
# Iteration 4038.
# # of particles to sample:51, stratum length:0.003504886592859561, uniform:0.002051101695063603
# Iteration 4039.
# # of particles to sample:20, stratum length:0.0011461778412698797, uniform:6.927678163577705e-05
# Iteration 4040.
# # of particles to sample:56, stratum length:0.0007933128597978538, uniform:0.0005583690054366622
# Iteration 4041.
# # of particles to sample:17, stratum length:0.00031352362542148913, uniform:0.00018150801653228025
# Iteration 4042.
# # of particles to sample:38, stratum length:0.0001663553223225357, uniform:7.758252423335192e-05
# Iteration 4043.
# # of particles to sample:39, stratum length:0.000194855421774378, uniform:0.00013717197876556798
# Iteration 4044.
# # of particles to sample:27, stratum length:0.000139580448268981, uniform:7.607841689061202e-05
# Iteration 4045.
# # of particles to sample:36, stratum length:0.0001712336396337684, uniform:1.636348936977849e-05
# Iteration 4046.
# # of particles to sample:45, stratum length:0.00018490252098941293, uniform:0.00011756621741169025
# Iteration 4047.
# # of particles to sample:32, stratum length:0.0003074028814045268, uniform:3.8164757980586e-05
# Iteration 4048.
# # of particles to sample:38, stratum length:0.0006224585471192973, uniform:0.0005956533758027214
# Iteration 4049.
# # of particles to sample:29, stratum length:0.00044237492190757517, uniform:4.524450363457396e-05

# %%
outlier_probs = []
changepoint_probs = []
for t in range(tt):
    pop = pops[t]
    outlier_prob = 0.
    changepoint_prob = 0.
    for n in range(pop.size()):
        state, weight = pop.at(n)
        if state.o == 2:
            outlier_prob += weight
        if state.s == 2:
            changepoint_prob += weight
    outlier_probs.append(outlier_prob)
    changepoint_probs.append(changepoint_prob)

# %%
fig, axes = plt.subplots(3, 1, figsize=(16, 8), sharex=True)

# Panel 1: Observations
axes[0].scatter(range(tt), Y[:tt], color='black')
axes[0].set_ylabel("Observation")
axes[0].set_title("Well-log Data and Posterior Inference")

# Panel 2: Changepoint posterior
axes[1].plot(changepoint_probs, color='red')
axes[1].set_ylabel("P(S_t = 2)")
axes[1].set_title("Changepoint Posterior Probability")

# Panel 3: Outlier posterior
axes[2].scatter(range(tt), outlier_probs, color='blue')
axes[2].set_ylabel("P(O_t = 2)")
axes[2].set_xlabel("Time")
axes[2].set_title("Outlier Posterior Probability")

plt.tight_layout()
plt.savefig("well_log_three_panel_plot.png", dpi=300)
plt.show()
