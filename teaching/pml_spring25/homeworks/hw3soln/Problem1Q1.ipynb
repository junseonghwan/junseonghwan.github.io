# %%
from problem1 import *

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dat = pd.read_csv("Y.csv", header=None)
Y = dat.to_numpy()
Y.shape
# Out:
# (500, 2)

# %%
# Hyper parameters
dp_concentration = 1.0
alpha = 1.
theta = 0.5
dim = 2
N = Y.shape[0]
mh_iter = 1000
gibbs_iter = 100

# %%
states = algorithm2(Y, dp_concentration, alpha, theta, gibbs_iter, mh_iter)
# Out:
# Number of cluster: 1
# Total data: 500
# Current log likelihood: -2506.925617108565
# Log likelihood after parameter update: -2135.539569775384
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -2134.8206518676498
# Log likelihood after parameter update: -2118.9590466878317
# Number of cluster: 1
# Total data: 500
# Current log likelihood: -2118.126507676425
# Log likelihood after parameter update: -2118.126507676425
# Number of cluster: 1
# Total data: 500
# Current log likelihood: -2118.126507676425
# Log likelihood after parameter update: -2118.184680423579
# Number of cluster: 1
# Total data: 500
# Current log likelihood: -2118.184680423579
# Log likelihood after parameter update: -2115.6232977902146
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -2109.3762621928527
# Log likelihood after parameter update: -2104.1312611224507
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -2094.0722900140418
# Log likelihood after parameter update: -2090.881038841996
# Number of cluster: 2
# Total data: 500
# Current log likelihood: -1986.8892517342595
# Log likelihood after parameter update: -1975.112601373094
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1705.084958752119
# Log likelihood after parameter update: -1658.5304731717583
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1589.62978771528
# Log likelihood after parameter update: -1516.4665752871383
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1352.7575723707112
# Log likelihood after parameter update: -1299.10565512726
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1205.303686370175
# Log likelihood after parameter update: -1148.9124447117742
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1130.9023221229297
# Log likelihood after parameter update: -1126.5030339204964
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1114.3799116780128
# Log likelihood after parameter update: -1110.9630833122785
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1124.6835203135588
# Log likelihood after parameter update: -1124.4210932803194
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1112.0556805323174
# Log likelihood after parameter update: -1102.012964364012
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -1108.0700010429455
# Log likelihood after parameter update: -1087.0033265896486
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -1077.1918396316305
# Log likelihood after parameter update: -1074.1733936218839
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1076.9077294544911
# Log likelihood after parameter update: -1076.2181450512312
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -1091.8011195680554
# Log likelihood after parameter update: -1091.549714186824
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1079.1210362677575
# Log likelihood after parameter update: -1078.027185389595
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1083.5440294528155
# Log likelihood after parameter update: -1076.8744269110352
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1062.1805238979923
# Log likelihood after parameter update: -1062.1805238979923
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1074.732916196354
# Log likelihood after parameter update: -1074.6701379970445
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1086.1535501213389
# Log likelihood after parameter update: -1087.0072001972587
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1070.6509895654574
# Log likelihood after parameter update: -1066.9322690619751
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1064.4946066915331
# Log likelihood after parameter update: -1064.4946066915331
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -1072.352211988359
# Log likelihood after parameter update: -1070.7638692112332
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1061.2144161081458
# Log likelihood after parameter update: -1063.9777577790228
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1070.1530426464105
# Log likelihood after parameter update: -1067.6161547458864
# Number of cluster: 7
# Total data: 500
# Current log likelihood: -1067.9522104245116
# Log likelihood after parameter update: -1065.2007056286411
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1079.4057378448945
# Log likelihood after parameter update: -1084.2714080628323
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1060.5026931915352
# Log likelihood after parameter update: -1058.4563271942127
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1059.3637695372008
# Log likelihood after parameter update: -1060.252889910971
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1058.0409710749716
# Log likelihood after parameter update: -1053.2075267355212
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1034.7723495548107
# Log likelihood after parameter update: -1033.1325856000158
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -1033.859704204564
# Log likelihood after parameter update: -1033.3704336116916
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -1022.8835128201682
# Log likelihood after parameter update: -1020.7128348771962
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -1018.7225712312407
# Log likelihood after parameter update: -1022.1831253793507
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -1032.61374091189
# Log likelihood after parameter update: -1025.9553964476956
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1022.6299751335238
# Log likelihood after parameter update: -1021.7881587481095
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1032.6637225248644
# Log likelihood after parameter update: -1032.885068258192
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1051.911954598132
# Log likelihood after parameter update: -1051.4870038954143
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1042.0112867089213
# Log likelihood after parameter update: -1042.0112867089213
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1044.4843552787863
# Log likelihood after parameter update: -1042.3205079173183
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -1034.435837960252
# Log likelihood after parameter update: -1035.0130169320319
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1026.5599218832742
# Log likelihood after parameter update: -1026.167323360337
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1032.777034744449
# Log likelihood after parameter update: -1031.6607247127788
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1034.9889115119588
# Log likelihood after parameter update: -1035.790380968864
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1034.8354365631765
# Log likelihood after parameter update: -1033.6673624428165
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1033.8595712467047
# Log likelihood after parameter update: -1033.1756157454324
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -1031.5732600303395
# Log likelihood after parameter update: -1032.6410924333543
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1036.005199483527
# Log likelihood after parameter update: -1032.965244548489
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1033.627235442403
# Log likelihood after parameter update: -1032.8775249698124
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1030.3187505951244
# Log likelihood after parameter update: -1034.6023720461997
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1033.5759274128798
# Log likelihood after parameter update: -1029.7518546437436
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -1017.2141205171146
# Log likelihood after parameter update: -1016.3796382071749

# %%
z = states[-1][0].astype(int)
cl_ids, cl_counts = np.unique(z, return_counts=True)
print(cl_ids)
print(cl_counts)
# Out:
# [0 1 2 3]
# [298  52 145   5]

# %%
params = states[-1][1]
print(params)
# Out:
# [{'mu': array([1.00418984, 3.25571595]), 'gamma': array([2.32976668, 1.33740839])}, {'mu': array([-3.53931535,  0.80558744]), 'gamma': array([1.52491327, 0.54097489])}, {'mu': array([-1.76446956, -1.46395406]), 'gamma': array([2.77866777, 1.74976987])}, {'mu': array([-0.55465928,  1.92284255]), 'gamma': array([2.11204019, 0.65094555])}]

# %%
cl_ids
# Out:
# array([0, 1, 2, 3])

# %%
x_min = np.min(Y[:,0]) - 1
x_max = np.max(Y[:,0]) + 1
y_min = np.min(Y[:,1]) - 1
y_max = np.max(Y[:,1]) + 1
x, y = np.mgrid[x_min:x_max:.01, y_min:y_max:.01]
pos = np.dstack((x, y))

dat = pd.DataFrame({"x": Y[:,0], "y": Y[:,1], "pred_z": z})
g = sns.relplot(data=dat, x="x", y="y", hue="pred_z")
# Calculate the density values
for k in cl_ids:
    rv = multivariate_normal(params[k]["mu"], np.diag(params[k]["gamma"]))
    z = rv.pdf(pos)
    plt.contour(x, y, z, levels=5, linewidths=1.5, alpha=1, cmap='viridis')

plt.xlabel('x')
plt.ylabel('y')

plt.grid(True)
plt.show()
#plt.savefig("pml-a3/problem1_q1_example_fig.png")
