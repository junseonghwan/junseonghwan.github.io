# %%
import numpy as np
import scipy
from scipy.stats import multivariate_normal, wishart
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from problem1 import *

# %%
dat = pd.read_csv("Y.csv", header=None)

# %%
Y = dat.to_numpy()
Y.shape
# Out:
# (500, 2)

# %% [markdown]
# ## Question 2
#
# Similar to Question 1 in structure:
#
# For each datum, we need to know which cluster it belongs to.
#
# For each table, we need to be able to remove a datum and add datum easily.
#
# Each table is associated with the hyperparameters of Normal-Wishart.
#
# \begin{align}
#     y_i | z_i, \theta &\sim \text{Normal}(\mu_{z_i}, \Gamma_{z_i}^{-1}) \\
#     \mu_k, \Gamma_{k} &\sim \text{NormalWishart}(\boldsymbol{\mu}_0, \kappa_0, \nu_0, V_0).
# \end{align}
#
# We choose $\boldsymbol{\mu}_0 = 0$, $\kappa_0 = 1$, $\nu = 2$, and $V0 = I$.
#
# With the above choices, the hyper-parameters update for cluster $k$ with $n$ data points,
#
# \begin{align*}
#     \kappa_k &= \kappa_0 + n \\
#     \boldsymbol{\mu}_{0,k} &= \frac{\kappa_0 \boldsymbol{\mu}_0 +  n \bar{y}_k}{\kappa_0 + n} \\
#     \nu_k &= \nu_0 + n \\
#     V_k &= \left( V^{-1} + \sum_{i : z_i = k} (y_i - \bar{y}_k) (y_i - \bar{y}_k)^T + \frac{\kappa_0 n}{\kappa_0 + n} (\bar{y}_k - \boldsymbol{\mu}_0)(\bar{y}_k - \boldsymbol{\mu}_0)^T \right)^{-1}.
# \end{align*}
#
# To facilitate efficient computation, we can track summary statistics for each cluster $k$:
#
# \begin{align}
#     \tilde{y}_{k,1} &= \sum_{i : z_i = k} y_i \\
#     \tilde{y}_{k,2} &= \sum_{i : z_i = k} y_i y_i^T.\\
# \end{align}
#
# Given these summary statistics, we can readily compute the NW parameters. And when we add a new datum to cluster $k$, updating these summary stats is simple.

# %%
# Hyper parameters
dp_concentration = 1.0
dim = 2
ident = np.diag(np.ones(dim))
prior_params = {"mu0": np.zeros(dim), "kappa0": 1., "nu0": dim, "V0": ident}
N = Y.shape[0]
gibbs_iter = 100

# %%
states = algorithm3(Y, dp_concentration, prior_params, gibbs_iter)
# Out:
# Assign datum: 164 to new cluster
# Assign datum: 475 to new cluster
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -6388.345757437483
# Assign datum: 13 to new cluster
# Assign datum: 48 to new cluster
# Assign datum: 74 to new cluster
# Assign datum: 401 to new cluster
# Assign datum: 483 to new cluster
# Number of cluster: 8
# Total data: 500
# Current log likelihood: -5893.547729520586
# Assign datum: 126 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -5549.365319868064
# Assign datum: 483 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -5005.010194151013
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -4690.3722100407795
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -4654.226768667235
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -4655.823122394195
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -4656.457689916733
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -4656.457689916733
# Assign datum: 71 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4638.39986818973
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -4653.31984143857
# Assign datum: 483 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4647.678811571184
# Assign datum: 315 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4649.199619378159
# Assign datum: 71 to new cluster
# Assign datum: 236 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4634.378246936901
# Assign datum: 221 to new cluster
# Assign datum: 343 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4602.998483505608
# Assign datum: 419 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4646.28594627317
# Assign datum: 366 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4628.517529011388
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4595.596564978796
# Assign datum: 74 to new cluster
# Assign datum: 492 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4646.8142356738335
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4650.476146793495
# Assign datum: 71 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4645.580176516483
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -4656.048571430304
# Assign datum: 100 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4646.243449466677
# Assign datum: 102 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4646.781444132123
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -4653.721363062442
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -4662.81472963122
# Assign datum: 79 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4639.204671954972
# Assign datum: 61 to new cluster
# Assign datum: 71 to new cluster
# Assign datum: 136 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4607.0472498838735
# Assign datum: 71 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4633.534816944138
# Assign datum: 195 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4646.64351387009
# Assign datum: 228 to new cluster
# Assign datum: 311 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4638.5222698682255
# Assign datum: 71 to new cluster
# Assign datum: 395 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4617.565168822235
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4604.754783521768
# Assign datum: 30 to new cluster
# Assign datum: 316 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4636.27781054496
# Assign datum: 113 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4627.75425531189
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4634.89624175339
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -4662.3953965144265
# Assign datum: 393 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4650.223415903376
# Assign datum: 162 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4625.717220532748
# Assign datum: 379 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4646.804181037574
# Assign datum: 167 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4647.078021319099
# Assign datum: 395 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4642.709126158674
# Assign datum: 3 to new cluster
# Assign datum: 71 to new cluster
# Assign datum: 175 to new cluster
# Assign datum: 188 to new cluster
# Assign datum: 290 to new cluster
# Assign datum: 372 to new cluster
# Number of cluster: 10
# Total data: 500
# Current log likelihood: -4552.854425418666
# Assign datum: 3 to new cluster
# Assign datum: 185 to new cluster
# Assign datum: 350 to new cluster
# Number of cluster: 10
# Total data: 500
# Current log likelihood: -4499.300985699875
# Assign datum: 236 to new cluster
# Assign datum: 349 to new cluster
# Number of cluster: 7
# Total data: 500
# Current log likelihood: -4523.605082672968
# Assign datum: 376 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4614.112410551184
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4620.466081820159
# Assign datum: 188 to new cluster
# Assign datum: 229 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4628.058569115945
# Assign datum: 321 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4631.112869159529
# Assign datum: 160 to new cluster
# Assign datum: 188 to new cluster
# Assign datum: 290 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4627.73231914052
# Assign datum: 200 to new cluster
# Assign datum: 274 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4625.105498872035
# Assign datum: 146 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4609.116851356747
# Assign datum: 30 to new cluster
# Assign datum: 349 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4629.790347407476
# Assign datum: 51 to new cluster
# Assign datum: 113 to new cluster
# Assign datum: 236 to new cluster
# Number of cluster: 7
# Total data: 500
# Current log likelihood: -4601.896197578367
# Assign datum: 71 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4608.615432591623
# Assign datum: 236 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4597.630943728653
# Assign datum: 249 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4611.2883368547045
# Assign datum: 3 to new cluster
# Assign datum: 82 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4626.1546015884505
# Assign datum: 118 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4647.334876946425
# Assign datum: 71 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4636.644839032166
# Assign datum: 71 to new cluster
# Assign datum: 298 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4621.5306135205965
# Assign datum: 311 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4605.894951786442
# Assign datum: 483 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4626.898947143329
# Assign datum: 3 to new cluster
# Assign datum: 82 to new cluster
# Assign datum: 167 to new cluster
# Assign datum: 351 to new cluster
# Assign datum: 417 to new cluster
# Number of cluster: 9
# Total data: 500
# Current log likelihood: -4591.1709344835235
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4619.431662543133
# Assign datum: 54 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4647.80250084211
# Assign datum: 114 to new cluster
# Assign datum: 196 to new cluster
# Assign datum: 382 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4633.898476765122
# Assign datum: 3 to new cluster
# Assign datum: 462 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4604.230934666594
# Assign datum: 150 to new cluster
# Assign datum: 471 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4630.908727612465
# Assign datum: 23 to new cluster
# Assign datum: 89 to new cluster
# Assign datum: 188 to new cluster
# Assign datum: 395 to new cluster
# Number of cluster: 7
# Total data: 500
# Current log likelihood: -4595.599325466768
# Assign datum: 221 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4647.399465698178
# Assign datum: 483 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4648.891708984931
# Assign datum: 71 to new cluster
# Assign datum: 466 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4631.970548328945
# Assign datum: 221 to new cluster
# Assign datum: 415 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4625.643598528418
# Assign datum: 71 to new cluster
# Assign datum: 113 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4617.924819734539
# Assign datum: 283 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4605.829183966846
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4601.435966170349
# Assign datum: 71 to new cluster
# Assign datum: 358 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4585.836212668755
# Assign datum: 15 to new cluster
# Assign datum: 280 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4626.979585002199
# Assign datum: 71 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4615.922499453646
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4589.189413120149
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4628.560340864567
# Assign datum: 142 to new cluster
# Assign datum: 236 to new cluster
# Assign datum: 290 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4602.495200301541
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -4648.163682204822
# Assign datum: 71 to new cluster
# Assign datum: 483 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4632.904144518975
# Assign datum: 3 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4630.1939982284475
# Number of cluster: 3
# Total data: 500
# Current log likelihood: -4658.141885669254
# Assign datum: 413 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4652.656428625524
# Assign datum: 71 to new cluster
# Assign datum: 188 to new cluster
# Assign datum: 236 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4610.2769328337
# Assign datum: 379 to new cluster
# Number of cluster: 4
# Total data: 500
# Current log likelihood: -4649.148529067757
# Assign datum: 250 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4631.4752423416485
# Assign datum: 71 to new cluster
# Assign datum: 104 to new cluster
# Assign datum: 262 to new cluster
# Assign datum: 484 to new cluster
# Number of cluster: 8
# Total data: 500
# Current log likelihood: -4604.3061453347755
# Assign datum: 92 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4589.65917261395
# Assign datum: 118 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4639.209118756854
# Assign datum: 75 to new cluster
# Assign datum: 146 to new cluster
# Assign datum: 167 to new cluster
# Assign datum: 188 to new cluster
# Number of cluster: 8
# Total data: 500
# Current log likelihood: -4559.355533904009
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4590.208092527579
# Assign datum: 71 to new cluster
# Assign datum: 236 to new cluster
# Assign datum: 311 to new cluster
# Number of cluster: 7
# Total data: 500
# Current log likelihood: -4581.958942838144
# Assign datum: 167 to new cluster
# Number of cluster: 7
# Total data: 500
# Current log likelihood: -4556.688310019867
# Assign datum: 132 to new cluster
# Number of cluster: 5
# Total data: 500
# Current log likelihood: -4606.121439348693
# Assign datum: 411 to new cluster
# Number of cluster: 6
# Total data: 500
# Current log likelihood: -4581.095217327745

# %%
z = states[-1].astype(int)
cl_ids, cl_counts = np.unique(z, return_counts=True)
print(cl_ids)
print(cl_counts)
z.shape
# Out:
# [0 1 2 3 4 5]
# [295   5  53 145   1   1]
# (500,)

# %%
# Estimate covariance matrix.
def posterior_normal_params(Y_k, n, prior_params):
    sum_y = Y_k.sum(axis=0)
    sum_y_sq = Y_k.T @ Y_k
    y_bar = sum_y / n
    dim = Y_k.shape[1]
    mu0 = prior_params["mu0"]
    k0 = prior_params["kappa0"]
    nu0 = prior_params["nu0"]
    V0 = prior_params["V0"]
    
    k_n = k0 + n
    nu_n = nu0 + n
    
    mu_n = (k0 * mu0 + sum_y)/k_n
    scatter_term = sum_y_sq - n * np.outer(y_bar, y_bar)
    mean_term = (k0 * n) / (k0 + n) * np.outer(y_bar - mu0, y_bar - mu0)
    V_n = V0 + scatter_term + mean_term
    #Sigma_n = np.linalg.inv(k_n * V_n)
    Sigma_n = V_n/k_n
    return mu_n, Sigma_n

# %%
posterior_params = []
for k in cl_ids:
    Y_k = Y[z == k,:]
    n = Y_k.shape[0]
    mu_n, Sigma_n = posterior_normal_params(Y_k, n, prior_params)
    posterior_params.append({"mu": mu_n, "Sigma": Sigma_n, "n_points": n})
    print(f"Cluster {k}: {n} data points.")
# Out:
# Cluster 0: 295 data points.
# Cluster 1: 5 data points.
# Cluster 2: 53 data points.
# Cluster 3: 145 data points.
# Cluster 4: 1 data points.
# Cluster 5: 1 data points.

# %%
posterior_params
# Out:
# [{'mu': array([0.9047303 , 3.29417515]),
#   'Sigma': array([[0.31693077, 0.15036125],
#          [0.15036125, 0.57938844]]),
#   'n_points': 295},
#  {'mu': array([0.51984827, 1.48794932]),
#   'Sigma': array([[0.51163551, 0.19368776],
#          [0.19368776, 1.00179675]]),
#   'n_points': 5},
#  {'mu': array([-3.45824398,  0.85359541]),
#   'Sigma': array([[0.90770025, 0.54934427],
#          [0.54934427, 1.89022304]]),
#   'n_points': 53},
#  {'mu': array([-1.81082728, -1.61848488]),
#   'Sigma': array([[0.21215194, 0.12079933],
#          [0.12079933, 0.43931317]]),
#   'n_points': 145},
#  {'mu': array([-0.2117636,  0.384638 ]),
#   'Sigma': array([[ 0.54484382, -0.08145233],
#          [-0.08145233,  0.64794639]]),
#   'n_points': 1},
#  {'mu': array([-0.05463851,  1.20407544]),
#   'Sigma': array([[ 0.50298537, -0.06578889],
#          [-0.06578889,  1.94979768]]),
#   'n_points': 1}]

# %%
x_min = np.min(Y[:,0]) - 1
x_max = np.max(Y[:,0]) + 1
y_min = np.min(Y[:,1]) - 1
y_max = np.max(Y[:,1]) + 1
x, y = np.mgrid[x_min:x_max:.01, y_min:y_max:.01]
pos = np.dstack((x, y))

dat = pd.DataFrame({"x": Y[:,0], "y": Y[:,1], "pred_z": z})
g = sns.relplot(data=dat, x="x", y="y", hue="pred_z")
# Calculate the density values
for k in cl_ids:
    if posterior_params[k]["n_points"] > 5:
        rv = multivariate_normal(posterior_params[k]["mu"], posterior_params[k]["Sigma"])
        zz = rv.pdf(pos)
        plt.contour(x, y, zz, levels=5, linewidths=1.5, alpha=1, cmap='viridis')

plt.xlabel('x')
plt.ylabel('y')

plt.grid(True)
plt.show()
#plt.savefig("pml-a3/problem1_q1_example_fig.png")
